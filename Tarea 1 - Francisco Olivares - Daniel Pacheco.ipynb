# %% [markdown]
# ## 1) Regresión Lineal

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import sklearn.linear_model as lm
import pylab
import scipy.stats as stats
from sklearn.model_selection import KFold
from IPython.display import display
import matplotlib.pyplot as plt
# %matplotlib inline
def parte1(arreglar = False):
    #=====================================================
    #PARTE A
    #=====================================================
    print("===================================")
    print("INICIO DE LA 1 A")
    print("===================================")
    df = pd.read_csv("kc_house_data.csv")
    df.drop(['id','date','zipcode',],axis=1,inplace=True)
    
    #IMPORTANTE PARA LA PREGUNTA F
    if arreglar == True:
        del df["sqft_above"]
        
    display(df.head())
    #=====================================================
    #PARTE B
    #=====================================================
    df.shape
    df.info()
    display(df.describe())
    #=====================================================
    #PARTE C
    #=====================================================
    print("===================================")
    print("INICIO DE LA 1 C")
    print("===================================")
    scaler = StandardScaler()
    df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    
    plt.figure(figsize = (16, 5))
    plt.hist(df_scaled['price'], bins = 10)
    plt.show()
    
    df_scaled['price'] = np.log(df['price'])
    
    plt.figure(figsize = (16, 5))
    plt.hist(df_scaled['price'], bins = 10)
    plt.show()
    #=====================================================
    #PARTE D
    #=====================================================

    X = df_scaled.iloc[:,1:] #use .ix instead, in older pandas version
    N = X.shape[0]
    X.insert(X.shape[1], 'intercept', np.ones(N))
    y = df_scaled['price']
    #mascara estatica con el 70% de los datos
    mascara = np.zeros(len(X))
    limit = int(len(X)*0.7)
    mascara[:limit] = 1 
    istrain = mascara== 1
    Xtrain = X[istrain]
    ytrain = y[istrain]
    Xtest = X[np.logical_not(istrain)]
    ytest = y[np.logical_not(istrain)]
    linreg = lm.LinearRegression(fit_intercept = False)
    modeloLineal = linreg
    linreg.fit(Xtrain, ytrain)
    
    #========================================================================================
    #PARTE E
    #========================================================================================
    print("===================================")
    print("INICIO DE LA 1 E")
    print("===================================")
    pesos = linreg.coef_ #el vector beta

    yEstimado = linreg.predict(Xtrain)
    yReal = np.array(ytrain)

    #Procedo a estimar la desviación estandar
    std = np.sqrt(sum(map(lambda x: x**2, (yReal - yEstimado))) / (len(yReal) - len(pesos)))

    
    #Procedo a sacar la diagonal de la pseudo matriz de covarianzas
    MatrizXTX = np.dot(np.asarray(Xtrain).T , np.asarray(Xtrain))

    V = np.linalg.inv(MatrizXTX).diagonal()
    valoresPropios = np.linalg.eigvals(MatrizXTX)
    print("Los valores propios son\n", valoresPropios)

    zScore = list()
    for i in range(len(pesos)):
        zScore.append(pesos[i] / (std * np.sqrt( V[i] )))

    a = list(df)[1:]
    a.append("origen")

    respuesta = [("Atributo", a ),("Peso", pesos) , ("Z-Score", zScore), ("Diagonal", V)]
    display(pd.DataFrame.from_items(respuesta))
    #=======================================================================================
    #PARTE F
    #=======================================================================================
    if arreglar == False:
        print("===================================")
        print("INICIO DE LA 1 F")
        print("===================================")    
        sospechosos = ["sqft_living", "sqft_living15" , "sqft_lot", "sqft_above", "sqft_basement"]
        for i in range(len(sospechosos)):
            for j in range(len(sospechosos)):
                if i<j:
                    x = np.asarray(df[sospechosos[i]])
                    y = np.asarray(df[sospechosos[j]])
                    plt.figure(figsize = (16, 5))
                    plt.scatter(x, y)            
                    plt.xlabel(sospechosos[i])
                    plt.ylabel(sospechosos[j])
                    plt.show()
    else:
        print("No se muestran los gráficos ya que se arregló el problema c:")
    #
    #PARTE G
    #
    print("===================================")
    print("INICIO DE LA 1 G")
    print("===================================")
    yhat_test = linreg.predict(Xtest)
    mse_test = np.mean(np.power(yhat_test - ytest, 2))
    Xm = Xtrain.as_matrix()
    ym = ytrain.as_matrix()
    def cve(k):
        kf = KFold(n_splits=k)
        mse_cv = 0
        for train, val in kf.split(Xm):
            linreg = lm.LinearRegression(fit_intercept = False)
            linreg.fit(Xm[train], ym[train])
            yhat_val = linreg.predict(Xm[val])
            mse_fold = np.mean(np.power(yhat_val - ym[val], 2))
            mse_cv += mse_fold
        mse_cv = mse_cv / k
        return mse_cv
    k_5 = cve(5)
    k_10 = cve(10)
    k_15 = cve(15)
    
    respuesta = [("15 Folds", [k_15] ),("10 Folds", [k_10]) , ("5 Folds", [k_5]), ("Error Prueba", [mse_test])]
    display(pd.DataFrame.from_items(respuesta))
    
    #print("Folds 5: "+str(k_5)+"\nFolds 10: "+str(k_10)+"\nError de entrenamiento: "+str(mse_test) )
    #
    #PARTE H
    #
    print("===================================")
    print("INICIO DE LA 1 H")
    print("===================================")
    yEstimado = np.asarray(modeloLineal.predict(Xtrain))
    yReal = np.asarray(ytrain)

    diferencias = yReal - yEstimado #np.power(yReal - yEstimado, 2)
    diferencias.sort()

    plt.figure(figsize = (16, 5))
    #measurements = np.random.normal(loc = 20, scale = 5, size=100)
    #display(measurements)
    stats.probplot(diferencias, dist="norm", plot=pylab)
    pylab.show()
    
#parte1()
parte1(arreglar = True)
# Out:
# ...
# INICIO DE LA 1 A
# ...
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_basement  yr_built  yr_renovated      lat  \
# 0     0          3      7              0      1955             0  47.5112
# 1     0          3      7            400      1951          1991  47.7210
# 2     0          3      6              0      1933             0  47.7379
# 3     0          5      7            910      1965             0  47.5208
# 4     0          3      8              0      1987             0  47.6168
#
#       long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# ## Desarrollo Regresión lineal
#
# ### a)
# <span style="font-size:12pt"> Debido a que lo que se quiere estudiar es el precio de las casas los atributos de id, fecha y código postal son irrelevantes, entonces se eliminan estas caracteristicas del dataset con la línea 4.
# Notar que la fecha y ubicación puede influr, pero en este caso todas las casa están en la misma locación y se venden en un corto periodo de tiempo (1 año).</span>
# ### b)
# <span style="font-size:12pt">Son 21613 entradas de datos, estas entradas tienen 18 atributos (precio, dormitorios, baños, etc) no nulos. Hay detalles estadisticos sobre el conjunto de muestra por atributo en la tabla que se muestra arriba con el metodo `.describe()`</span>
# ### c)
# <span style="font-size:12pt">
# En las mediciones se midieron 18 atributos distintos, en diferentes escalas, dinero, cantidad de piezas, baños, etc. Entonces para dejar todas las cantidades en la misma escala es necesario realizar la estandarización. <br>
# Al ver el histograma del precio después de estandarizar se aprecia que la gran mayoria de los datos se concetra al inicio (pegados al eje y), entonces es necesario realizar una transformación para que los datos se repartan de mejor manera a lo largo del eje. Se observa que los datos presentan un comportamiento exponencial decreciente, entonces se aplica el logaritmo para que así estos se puedan diferenciar unos de otros.
# </span>
# ### d)
# <span style="font-size:12pt">
# El modelo de regresión lineal es
# $$ y = \beta_0 + \sum_{j=1}^{p} \beta_j x_j  $$
# Se puede meter el termino $\beta_0$ dentro del vector $\beta$ si es que al final de cada muestra (matriz $X$) se añade un 1, entonces al momento de resolver el sistema $X \cdot \beta = Y$, dentro del vector $\beta$ la última fila será el $\beta_0$.<br>
# Lo que hace la linea 4 es exactamente añadir una columna de 1's a la matriz $X$.<br>
# <br>
# Los parámetros usados en la regresión lineal<br>
# Para la función `lm.LinearRegression()`<br>
# * fit_intercept = False. Sirve para ver si se va a calcular o no el intercepto, por defaul True<br>
# * normalize = Se ignora si fit_intercept es False. Si es True la data X va a ser normalizada<br>
# * copy_X = Boleano que dice si las operaciones serán o no inplace (default True)<br>
# * n_jobs = los jobs usados para el procesamiento (default True)<br>
#
# <span style="font-size:12pt">
# Para el método `fit()`<br>
# * X = La matriz $X$
# * y = El vector y de soluciones conocidas para el input $X$
# </span>
#
# ### e)
# <span style="font-size:12pt">
# El z-score se calcula como $$\textit{z-score} = \frac{\hat{\beta_j}}{\hat{\sigma} \cdot \sqrt{\upsilon_{jj}}}$$
# <span style="font-size:12pt">
# Donde $\hat{\beta_j}$ corresponden a los pesos del atributo j, $\hat{\sigma}$ es la desviación estandar calculada de la forma $$\hat{\sigma} = \frac{\sqrt{ \sum_{i=1}^{n} (y^{(i)} - \hat{y}^{(i)})^2}} {n - d - 1}$$
# <span style="font-size:12pt">
# y $\upsilon_{jj}$ corresponde a la diagonal de la pseudo matriz de covarianzas (le faltaría el $\frac{1}{n}$), es decir $$\upsilon_{jj} = (X^{T} \cdot X)^{-1} _{jj}$$
# Entonces así se obtuvo la tabla de arriba.
# <span style="font-size:12pt">
# Se observa que 3 de los valores del z-score dan NaN, esto ocurre dado que algunos $\upsilon_{jj}$ son negativos. Esto se produce ya que la Matriz $X^{T} \cdot X$ esta al borde de ser singular dado que uno de sus valores propios está muy cerca del 0 (-2.29675177e-12), entonces al momento de sacar la inversa se generan esos $\upsilon_{jj}$ negativos.
# <span style="font-size:12pt">
# Notar que si uno de los valores propios está muy cerca del 0 eso significa que alguno o alguno(s) atributos son linealmente dependientes.<br><br>
# Los z-score con magnitud mayor a 1.96 son los atributos significativos, mientras más z-score más significativo.
# </span>
# ### f)
# <span style="font-size:12pt">
# Al ver que que uno de los valores propios era cercano a 0 (-2.29675177e-12) se decide arbitrariamente gráficar atributos para ver ver si es que existe alguno que sea combinación lineal de otro, como se ven en los gráficos de arriba el atributo sqft_living y sqft_above parecieran estar relacionados, entonces se decide eliminar(arbitrariamente) el atributo sqft_above puesto que no añadiría nueva información, una vez hecho esto se aprecian que ya no existen z-score definidos como NaN<br>
# NOTA: Si quiere ver el resultado de eliminar sqft_above llame a parte1() con el parametro arreglado=True como se muestra comentado.</span>
#
# ### g)
# <span style="font-size:12pt">
# Al ver los valores de error(cv) y compararlos con el error de prueba se aprecia que estos 3 valores se acercan al error de prueba. Estos valores no presentan una diferencia significativa que nos diga algo sobre el número óptimo de folds.
# </span>
#
# ### h)
#
# <span style="font-size:12pt">
# Si es razonable la hipótesis de normalidad dado que la gran mayoría de los residuos permanecen en la recta corroborando que efectivamente se distribuian normalmente.
# </span>

# %% [markdown]
# # 2 Selección de atributos

# %%
def parte2():
    df = pd.read_csv("kc_house_data.csv")
    df.drop(['id','date','zipcode','sqft_above'],axis=1,inplace=True)
    scaler = StandardScaler()
    df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    df_scaled['price'] = np.log(df['price'])
    X = df_scaled.iloc[:,1:] #use .ix instead, in older pandas version
    N = X.shape[0]
    X.insert(X.shape[1], 'intercept', np.ones(N))
    y = df_scaled['price']
    #mascara estatica con el 70% de los datos
    mascara = np.zeros(len(X))
    limit = int(len(X)*0.7)
    mascara[:limit] = 1 
    istrain = mascara== 1
    Xtrain = X[istrain]
    ytrain = y[istrain]
    Xtest = X[np.logical_not(istrain)]
    ytest = y[np.logical_not(istrain)]
    def fss(x, y, names_x, k = 10000):     
        p = x.shape[1]-1 #numero de columnas - 1
        k = min(p, k) #cantidad maxima de atributos
        names_x = np.array(names_x) 
        remaining = [i for i in range(0, p)] #lista de 0 a 16 considerando los 17 primeros
        selected = [p] #parto seleccionando el intercepto
        current_score = best_new_score = 0.0
        ejeX = [i for i in range(1,p+1)]
        erroresEntrenamiento = list()
        erroresPrueba = list()
        while remaining and len(selected)<=k :
            score_candidates = []
            for candidate in remaining:
                model = lm.LinearRegression(fit_intercept=False)
                indexes = selected + [candidate]
                x_train = x[:,indexes]

                x_test = Xtest.as_matrix()[:,indexes]
                y_test = ytest.as_matrix()

                modeloEntrenado = model.fit(x_train, y)
                predictions_train = modeloEntrenado.predict(x_train)
                residuals_train = predictions_train - y

                residuoTest = modeloEntrenado.predict(x_test) - y_test
                #rmse_test = np.sqrt(sum(np.power(residuoTest, 2)) * (1.0/len(residuoTest)))

                mse_candidate = np.mean(np.power(residuals_train, 2))
                mse_test = np.mean(np.power(residuoTest, 2))

                rmse_candidate = np.sqrt(sum(np.power(residuals_train, 2)) * (1.0/len(residuals_train)))
                
                #=========================================================================================
                #SE PROCEDE A SACAR EL Z-SCORE
                #=========================================================================================
                pesos = modeloEntrenado.coef_ #el vector beta

                yEstimado = predictions_train
                yReal = y

                #Procedo a estimar la desviación estandar
                std = np.sqrt(sum(map(lambda x: x**2, (yReal - yEstimado))) / (len(yReal) - len(pesos)))

                #Procedo a sacar la diagonal de la pseudo matriz de covarianzas
                MatrizXTX = np.dot(np.asarray(x_train).T , np.asarray(x_train))

                V = np.linalg.inv(MatrizXTX).diagonal()

                zScore = list()
                for i in range(len(pesos)):
                    zScore.append(abs(pesos[i] / (std * np.sqrt( V[i] ))))
                zScore = sum(zScore)
                #==========================================================================================
                #FIN DEL CALCULO DEL Z-SCORE
                #==========================================================================================
                
                score_candidates.append((zScore, mse_candidate, candidate, mse_test))

            score_candidates.sort()
            #score_candidates[:] = score_candidates[::-1]        
            _, best_new_score, best_candidate, errorDePrueba = score_candidates.pop()

            erroresEntrenamiento.append(best_new_score)
            erroresPrueba.append(errorDePrueba) 

            remaining.remove(best_candidate)
            selected.append(best_candidate)
            print ("selected = %s ..."%names_x[best_candidate])
            print ("totalvars=%d, rmse = %f"%(len(indexes),best_new_score))

        plt.figure(figsize = (16, 5))

        plt.plot(ejeX, erroresEntrenamiento, ".-")
        plt.plot(ejeX, erroresPrueba, ".-")

        plt.legend(["Entrenamiento", "Prueba"])
        plt.xlabel("Numero de atributos")
        plt.ylabel("Errores")

        plt.show()

        return selected
    names_regressors = Xtrain.columns[:-1] #without intercept
    print(fss(Xtrain.as_matrix(),ytrain.as_matrix(),names_regressors))
parte2()
# Out:
# selected = grade ...
# totalvars=2, rmse = 0.143260
# selected = lat ...
# totalvars=3, rmse = 0.103340
# selected = sqft_living ...
# totalvars=4, rmse = 0.084960
# selected = yr_built ...
# totalvars=5, rmse = 0.075447
# selected = view ...
# totalvars=6, rmse = 0.071782
# selected = condition ...
# totalvars=7, rmse = 0.070299
# selected = sqft_living15 ...
# totalvars=8, rmse = 0.068455
# selected = bathrooms ...
# totalvars=9, rmse = 0.066864
# selected = waterfront ...
# totalvars=10, rmse = 0.065836
# selected = floors ...
# totalvars=11, rmse = 0.065107
# selected = sqft_lot ...
# totalvars=12, rmse = 0.064820
# selected = yr_renovated ...
# totalvars=13, rmse = 0.064619
# selected = bedrooms ...
# totalvars=14, rmse = 0.064583
# selected = sqft_lot15 ...
# totalvars=15, rmse = 0.064554
# selected = sqft_basement ...
# totalvars=16, rmse = 0.064527
# selected = long ...
# totalvars=17, rmse = 0.064516
# [16, 8, 12, 2, 10, 6, 7, 14, 1, 5, 4, 3, 11, 0, 15, 9, 13]

# %% [markdown]
# ### 2 a)
# <span style="font-size:12pt">
# La heuristica utilizada para resolver el problema fue escoger el atributo que provocara el mayor aumento posible en el valor de la suma de las magnitudes de todos los z-score, así se obtiene el gráfico mostrado en la parte superior. El enfoque utilizado es similar al de Backward stepwise selection.
#
# ### IMPORTANTE: Se eliminó el atributo 'sqft_above' del dataset para poder calcular todos los z-score.

# %% [markdown]
# ## 3 Regularización

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
import matplotlib.pylab as plt
def parte3():
    df = pd.read_csv("kc_house_data.csv")
    df.drop(['id','date','zipcode',],axis=1,inplace=True)
    scaler = StandardScaler()
    df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    df_scaled['price'] = np.log(df['price'])
    X = df_scaled.iloc[:,1:] #use .ix instead, in older pandas version
    N = X.shape[0]
    X.insert(X.shape[1], 'intercept', np.ones(N))
    y = df_scaled['price']
    #mascara estatica con el 70% de los datos
    mascara = np.zeros(len(X))
    limit = int(len(X)*0.7)
    mascara[:limit] = 1 
    istrain = mascara== 1
    Xtrain = X[istrain]
    ytrain = y[istrain]
    Xtest = X[np.logical_not(istrain)]
    ytest = y[np.logical_not(istrain)]    
    
    X2 = X.drop('intercept', axis=1,inplace=False)
    Xtrain = X2[istrain]
    ytrain = y[istrain]
    names_regressors = X2.columns
    alphas_ = np.logspace(7,1,base=10)
    coefs = []
    model = Ridge(fit_intercept=True,solver='svd')
    for a in alphas_:
        model.set_params(alpha=a)
        model.fit(Xtrain, ytrain)
        coefs.append(model.coef_)
    plt.figure(figsize = (16,8))
    ax = plt.gca()
    for y_arr, label in zip(np.squeeze(coefs).T, names_regressors):
        plt.plot(alphas_, y_arr, label=label)
    plt.legend()
    ax.set_xscale('log')
    ax.set_xlim(ax.get_xlim()[::-1]) # reverse axis
    plt.title('Regularization Path RIDGE')
    plt.axis('tight')
    plt.legend(loc=2)
    plt.show()
    
    '''
    nombre = list(Xtrain.std().index)
    varianza = np.power(np.asarray(Xtrain.std()),2)
    lista = [ (varianza[i], nombre[i]) for i in range(len(nombre))]
    lista.sort()
    print(lista)
    '''
    
    X2 = X.drop('intercept', axis=1,inplace=False)
    Xtrain = X2[istrain]
    ytrain = y[istrain]
    names_regressors = X2.columns
    alphas_ = np.logspace(0,-3,base=10)
    coefs = []
    model = Lasso(fit_intercept=True)
    for a in alphas_:
        model.set_params(alpha=a)
        model.fit(Xtrain, ytrain)
        coefs.append(model.coef_)
    plt.figure(figsize = (16,8))
    ax = plt.gca()
    for y_arr, label in zip(np.squeeze(coefs).T, names_regressors):
        plt.plot(alphas_, y_arr, label=label)
    plt.legend()
    ax.set_xscale('log')
    ax.set_xlim(ax.get_xlim()[::-1]) # reverse axis
    plt.title('Regularization Path LASSO')
    plt.axis('tight')
    plt.legend(loc=2)
    plt.show()
    
    Xtest = X2[np.logical_not(istrain)]
    ytest = y[np.logical_not(istrain)]
    alphas_ = np.logspace(7,1,base=10)
    coefs = []
    model = Ridge(fit_intercept=True,solver='svd')
    mse_test = []
    mse_train = []
    for a in alphas_:
        model.set_params(alpha=a)
        model.fit(Xtrain, ytrain)
        yhat_train = model.predict(Xtrain)
        yhat_test = model.predict(Xtest)
        mse_train.append(np.mean(np.power(yhat_train - ytrain, 2)))
        mse_test.append(np.mean(np.power(yhat_test - ytest, 2)))
    plt.figure(figsize = (16,8))
    ax = plt.gca()
    ax.plot(alphas_,mse_train,label='train error ridge')
    ax.plot(alphas_,mse_test,label='test error ridge')
    plt.title('Ridge')
    plt.legend(loc=1)
    ax.set_xscale('log')
    ax.set_xlim(ax.get_xlim()[::-1])
    plt.show()
    
    def MSE(y,yhat): return np.mean(np.power(y-yhat,2))
    Xm = Xtrain.as_matrix()
    ym = ytrain.as_matrix()
    from sklearn.model_selection import KFold
    kf = KFold(n_splits=10)
    best_cv_mse = float("inf")
    model = Ridge(fit_intercept=True,solver='svd')
    alphas_ = alphas_ = np.logspace(7,1,base=10)
    for a in alphas_:
        model.set_params(alpha=a)
        mse_list_k10 = [MSE(model.fit(Xm[train], ym[train]).predict(Xm[val]), ym[val]) for train, val in kf.split(Xm)]
        if np.mean(mse_list_k10) < best_cv_mse:
            best_cv_mse = np.mean(mse_list_k10)
            best_alpha = a
            print ("BEST PARAMETER=%f, MSE(CV)=%f"%(best_alpha,best_cv_mse))


    
parte3()
# Out:
# BEST PARAMETER=10000000.000000, MSE(CV)=0.275499
# BEST PARAMETER=7543120.063355, MSE(CV)=0.274855
# BEST PARAMETER=5689866.029018, MSE(CV)=0.274008
# BEST PARAMETER=4291934.260129, MSE(CV)=0.272894
# BEST PARAMETER=3237457.542818, MSE(CV)=0.271436
# BEST PARAMETER=2442053.094549, MSE(CV)=0.269531
# BEST PARAMETER=1842069.969327, MSE(CV)=0.267057
# BEST PARAMETER=1389495.494373, MSE(CV)=0.263865
# BEST PARAMETER=1048113.134155, MSE(CV)=0.259777
# BEST PARAMETER=790604.321091, MSE(CV)=0.254598
# BEST PARAMETER=596362.331659, MSE(CV)=0.248125
# BEST PARAMETER=449843.266897, MSE(CV)=0.240168
# BEST PARAMETER=339322.177190, MSE(CV)=0.230586
# BEST PARAMETER=255954.792270, MSE(CV)=0.219331
# BEST PARAMETER=193069.772888, MSE(CV)=0.206492
# BEST PARAMETER=145634.847750, MSE(CV)=0.192326
# BEST PARAMETER=109854.114199, MSE(CV)=0.177258
# BEST PARAMETER=82864.277285, MSE(CV)=0.161835
# BEST PARAMETER=62505.519253, MSE(CV)=0.146650
# BEST PARAMETER=47148.663635, MSE(CV)=0.132252
# ...

# %% [markdown]
# ## Desarrollo Regularización
# ### a)
# <span style="font-size:12pt">
# La linea 3 y 9 son para dejar el intercepto afuera de la penalización de ridge.<br>
# En ridge el parámetro $\lambda$ viene a ser de cierta manera con la fuerza que esta filtrando el regularizador, se aprecia que con ordenes grandes ($10^7$) los parámetros tienden a 0, en la medida que el valor de $\lambda$ se acerca a 0 la penalización del regularizador pierde efecto.
# </span>
# ### b)
# <span style="font-size:12pt">
# Se sabe que el valor de $\lambda$ en lasso define un peso mínimo que deben de superar los atributos para ser considerados, es decir si el atributo tiene peso $p$ con $p < |\lambda|$ le es asignado peso 0. Si es más efectivo (comparadolo con ridge) puesto que por dentro el algoritmo selecciona atributos naturalmente (los no enviados a 0).
# </span>
# ### c)
# <span style="font-size:12pt">
# Se escoge el regularizador de Ridge debido a que este no manda a 0 los atributos, puesto que creemos que todos los atributos son importantes para realizar el modelo.
# </span>
# ### d)
# <span style="font-size:12pt">
# El mejor parámetro resulta ser $\lambda = 30.888436$ puesto que mínimiza el error(cv). Este valor esta al borde del intervalo utilizado, entonces esto nos quiere decir que se quiere regularizar muy poco dado que la regresión lineal simple ya generaba muy buenos valores de $\beta$
# </span>

# %% [markdown]
# ## 4) Drift

# %%
def parte4():
    df = pd.read_csv("kc_house_data.csv")
    df.drop(['id','date','zipcode',],axis=1,inplace=True)
    scaler = StandardScaler()
    df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    df_scaled['price'] = np.log(df['price'])
    X = df_scaled.iloc[:,1:] #use .ix instead, in older pandas version
    N = X.shape[0]
    X.insert(X.shape[1], 'intercept', np.ones(N))
    y = df_scaled['price']
    #mascara estatica con el 70% de los datos
    mascara = np.zeros(len(X))
    limit = int(len(X)*0.7)
    mascara[:limit] = 1 
    istrain = mascara== 1
    Xtrain = X[istrain]
    ytrain = y[istrain]
    Xtest = X[np.logical_not(istrain)]
    ytest = y[np.logical_not(istrain)] 
    
    df_A = df_scaled.sample(1000,random_state=11)
    frames = []
    valor = df_scaled.price
    length = 0.3
    for z in np.arange(int(np.min(valor)),int(np.max(valor))+1,length):
        aux = df_scaled[(df_scaled.price >= z) & (df_scaled.price < z+length)].head(100)
        frames.append(aux)
    df_B = pd.concat(frames).sample(1000,random_state=11)
    
    
    X_A = df_A.iloc[:,1:].values
    y_A = df_A.price
    X_B = df_B.iloc[:,1:].values
    y_B = df_B.price
    from sklearn.model_selection import train_test_split
    Xtrain_A,Xval_A,ytrain_A,yval_A = train_test_split(X_A, y_A, test_size=0.3, random_state=42)
    Xtrain_B,Xval_B,ytrain_B,yval_B = train_test_split(X_B, y_B, test_size=0.3, random_state=42)
    
    
    model = lm.LinearRegression(fit_intercept=True)
    model.fit(Xtrain_A, ytrain_A)
    predictionsVal_AA = model.predict(Xval_A)
    residualsVal_AA = predictionsVal_AA - yval_A
    mse_AA = np.mean(np.power(residualsVal_AA, 2))
    print("Error train A en validación A:", mse_AA)

    predictionsVal_AB = model.predict(Xval_B)
    residualsVal_AB = predictionsVal_AB - yval_B
    mse_AB = np.mean(np.power(residualsVal_AB, 2))
    print("Error train A en validacion B:", mse_AB)

    model = lm.LinearRegression(fit_intercept=True)
    model.fit(Xtrain_B, ytrain_B)
    predictionsVal_BA = model.predict(Xval_A)
    residualsVal_BA = predictionsVal_BA - yval_A
    mse_BA = np.mean(np.power(residualsVal_BA, 2))
    print("Error train B en validación A:", mse_BA)

    predictionsVal_BB = model.predict(Xval_B)
    residualsVal_BB = predictionsVal_BB - yval_B
    mse_BB = np.mean(np.power(residualsVal_BB, 2))
    print("Error train B en validación B:", mse_BB)
    
    #print("Varianza set A", np.var(y_A))
    #print("Varianza set B", np.var(y_B))
    
parte4()
# Out:
# Error train A en validación A: 0.07160600373421917
# Error train A en validacion B: 0.15156342857368943
# Error train B en validación A: 0.08289418218202484
# Error train B en validación B: 0.11895514203211843

# %% [markdown]
# ## Desarrollo Drift
# ### b)
# <span style="font-size:12pt">
# Las predicciones del set de validación se comportan mejor cuando se evaluan en la máquina entrenada con el conjunto de entrenamiento correspondiente.
# </span>
# ### c)
# <span style="font-size:12pt">
# Escogeriamos B, porque está mejor preparada para casos generales dado que el dataset de B considera varias muestras de todo tipo de precio de casas, en cambio la máquina A no se comportará bien cuando tenga que predecir precios de los extremos. Esto es un ejemplo de transfer learning de la máquina B pues puede hacer buenas predicciones en distribuciones para las que no fue entrenada.
# </span>

# %%
from sklearn.metrics import accuracy_score
def parte5():
    #================================================
    #PARTE A
    #================================================
    headers = ['age','sex','chest_pain','blood_p','serum','blood_s','electro','max_heart', 'angina','oldpeak','slope','vessel','thal','normal']
    df = pd.read_csv("heart.dat", header=None, names=headers, sep=' ')
    
    #display(df.head())
    #scaler = StandardScaler()
    #df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

    # Cheackear como se distribuye el atributo
    #plt.figure(figsize = (16, 5))
    #plt.hist(df_scaled['max_heart'], bins = 10)
    #plt.show()
    
    X = df.drop(["max_heart","normal"], axis = 1, inplace = False) #Gran matriz X que le quite el atributo del precio
    #use .ix instead, in older pandas version
    N = X.shape[0]#Cantidad de filas
    #X.insert(X.shape[1], 'intercept', np.ones(N))#Pega una columna de 1's
    y = df["max_heart"]
    
    mascara = np.zeros(len(X))
    limit = int(len(X)*0.7)
    mascara[:limit] = 1
    istrain = mascara== 1
    Xtrain = X[istrain]
    ytrain = y[istrain]
    Xtest = X[np.logical_not(istrain)]
    ytest = y[np.logical_not(istrain)]
    #===================================================
    #PARTE B
    #===================================================
    linreg = lm.LinearRegression(fit_intercept = True, normalize = True)
    linreg.fit(Xtrain, ytrain)    

    df_entrenamiento = df[istrain]
    df_prueba = df[np.logical_not(istrain)]
    a = df_entrenamiento.index[df_entrenamiento["normal"] == 1]
    b = df_entrenamiento.index[df_entrenamiento["normal"] == 2]
    sanos = df_entrenamiento["max_heart"].iloc[a]
    enfermos = df_entrenamiento["max_heart"].iloc[b]
    
    umbral = (np.mean(np.asarray(sanos)) + np.mean(np.asarray(enfermos)))/2.0
    
    def clasificar(x, u):
        if x>=u: 
            return 1
        else:
            return 2
    predicciones = [clasificar(i, umbral) for i in list(linreg.predict(Xtrain))]    
    print ("Score entrenamiento: ",(accuracy_score(list(df_entrenamiento["normal"]),predicciones)))
    
    prediccionesPrueba = [clasificar(i, umbral) for i in list(linreg.predict(Xtest))]   
    print ("Score prueba: ",(accuracy_score(list(df_prueba["normal"]),prediccionesPrueba)))
    
parte5()
# Out:
# Score entrenamiento:  0.724867724868
# Score prueba:  0.802469135802
